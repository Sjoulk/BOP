# %%
import matplotlib.pyplot as plt
import numpy as np
import math as m

x_punkter1 = np.array([0, 5])
y_punkter1 = np.array([0, 250])

plt.plot(x_punkter1, y_punkter1)
plt.show()

# %%
x_verdier = np.array([0, 1, 2, 3, 4, 5, 6])
y_verdier = np.sin(x_verdier)

plt.plot(x_verdier, y_verdier)
plt.show()

# %%
x_verdier2 = np.linspace(0, 2*np.pi, 15) #15 verdider fra 0 til 2pi
y_verdier2 = np.sin(x_verdier2)

plt.plot(x_verdier2, y_verdier2)
plt.show()

# %%
x_verdier4 = np.arange(-1, 4, .1) #avstand mellom points=0,1. siste verdi blir 3,9
y_verdier4 = 0.5*x_verdier4**3 - 2*x_verdier4**2 + x_verdier4 +2

plt.plot(x_verdier4, y_verdier4)
plt.show()

# %%
x_verdier2 = np.linspace(0, 2*np.pi, 36) #36 verdier fra 0 til 2pi
sinusverdier = np.sin(x_verdier2)
cosinusverdier = np.cos(x_verdier2)

plt.plot(x_verdier2, sinusverdier)
plt.plot(x_verdier2, cosinusverdier)
plt.show()

# %%
x_verdier2 = np.linspace(0, 2*np.pi, 36) # 36 values fra 0 til 2pi
sinusverdier = np.sin(x_verdier2)
cosinusverdier = np.cos(x_verdier2)

plt.plot(x_verdier2, sinusverdier, '.r', label='sin(x)')
plt.plot(x_verdier2, cosinusverdier, '-g', lw=3, label='cos(x)')
plt.title("Sinus og Cosinuskurver")
plt.xlabel("x")
plt.ylabel("sin(x), cos(x)")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math as m

x_verdier1 = np.linspace(0, 2*np.pi, 36) #36 values fra 0 til 2pi
y_verdier1 = np.sin(x_verdier1)

plt.plot(x_verdier1, y_verdier1)
plt.grid()
plt.show()

# %%
x_values2 = np.linspace(0, 360, 36) #36 verdier fra 0 til 360 grader
y_values2 = np.sin(x_values2*(np.pi)/180)

plt.plot(x_values2, y_values2, '-b')
plt.xticks(np.arange(0, 361, 30)) # for å inkludere 360 må vi ha med 361 som parameter
plt.grid()
plt.axhline(c='k', lw=2)
plt.axvline(c='k', lw=2)
plt.title("Sinus til vinkler i grader")
plt.xlabel("Vinkel(v) i grader")
plt.ylabel("sin(v)")

plt.show()

# %%
x_verdier4 = np.arange(-1, 4, .1) # avstand mellom punktene er 0,1. Siste verdi i arrayen blir 3,9
y_verdier4 = 0.5*x_verdier4**3 - 2*x_verdier4**2 + x_verdier4 + 2

plt.plot(x_verdier4, y_verdier4)
plt.grid()
plt.axhline(c='k', lw=2)
plt.axvline(c='k', lw=2)
plt.show()

# %%
x = np.linspace (0, 2*np.pi, 6);
y = np.sin(x);
z = np.cos(x);
plt.plot (z, y)
plt.show()

# %%
x = np.linspace (0, 2*np.pi, 30);
y = np.sin(x);
z = np.cos(x);
plt.plot (z, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 8] # Dette er for å få en større figur

hastighet_100 = 100/3.6  # gjør 100 km/t om til m/s
t_0_100 = 4.4      # tiden blien skulle bruke på 0-100 km/t
tidsvektor = np.arange(0, 10.1, 0.5)      # 0 til 5 sek med halv sek oppløsning

akselerasjon = 5 #hastighet_100 / t_0_100    # beregner akselerasjon
strekning = 0.5 * akselerasjon * tidsvektor**2    # beregner strekningen i meter
# Strekning blir en array med like mange elementer som tidsvektor
# fart_kmt = akselerasjon * tidsvektor * 3.6 # beregner hastighet i km/t
fart_ms = akselerasjon * tidsvektor * 3.6

plt.plot(tidsvektor, strekning, label='Strekning (m)')
plt.plot(tidsvektor, fart_ms, label='Hastighet (km/t)')
plt.yticks(np.arange(0, 251, 25))
plt.grid()      # legger på rutenett
plt.axhline(c='k', lw=2)     # uthever x-aksen
plt.axvline(c='k', lw=2)     # uthever y-aksen
plt.title(" Fart og strekning kjørt ved konstant akselerasjon")
plt.xlabel("sekunder fra start")     # tekst på x-aksen
plt.ylabel("Strekning i meter og fart i km/t")     # tekst på x-aksen
plt.legend()     # viser figurforklaring kurvetyper (farge) med «label» 
plt.show()       # viser figuren

# %%
import matplotlib.pyplot as plt

plt.plot (y, x)
plt.show()
